# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')
train.head()
train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
train = train.drop(columns=['PassengerId', 'Name', 'Cabin', 'Ticket'])
test_ids = test['PassengerId']
test = test.drop(columns=['PassengerId', 'Name', 'Cabin', 'Ticket'])
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_cols = ['Sex', 'Embarked']

label_encoder = LabelEncoder()

for col in categorical_cols:
    train[col] = label_encoder.fit_transform(train[col])
    test[col] = label_encoder.transform(test[col])

train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
train['Age'].fillna(train['Age'].mean(), inplace=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(train.drop(columns=['Survived']), train['Survived'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1], )),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 64)             │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 577 (2.25 KB)
#  Trainable params: 577 (2.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=50)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4895 - loss: 2.9109 - val_accuracy: 0.6682 - val_loss: 1.3024
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6961 - loss: 1.0471 - val_accuracy: 0.6502 - val_loss: 0.8080
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6916 - loss: 0.6790 - val_accuracy: 0.6637 - val_loss: 0.5889
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6961 - loss: 0.5799 - val_accuracy: 0.6592 - val_loss: 0.5874
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7051 - loss: 0.5737 - val_accuracy: 0.6637 - val_loss: 0.5751
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7036 - loss: 0.5628 - val_accuracy: 0.6906 - val_loss: 0.5649
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7066 - loss: 0.5619 - val_accuracy: 0.6682 - val_loss: 0.5791
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7111 - loss: 0.5475 - val_accuracy: 0.6861 - val_loss: 0.5574
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7171 - loss: 0.5511 - val_accuracy: 0.6726 - val_loss: 0.5708
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7305 - loss: 0.5470 - val_accuracy: 0.6996 - val_loss: 0.5489
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7126 - loss: 0.5350 - val_accuracy: 0.6996 - val_loss: 0.5524
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7246 - loss: 0.5296 - val_accuracy: 0.7040 - val_loss: 0.5393
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7231 - loss: 0.5260 - val_accuracy: 0.6996 - val_loss: 0.5378
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7290 - loss: 0.5212 - val_accuracy: 0.6996 - val_loss: 0.5401
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7380 - loss: 0.5273 - val_accuracy: 0.7175 - val_loss: 0.5382
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7216 - loss: 0.5292 - val_accuracy: 0.7130 - val_loss: 0.5393
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7335 - loss: 0.5203 - val_accuracy: 0.7130 - val_loss: 0.5234
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7410 - loss: 0.5075 - val_accuracy: 0.7130 - val_loss: 0.5422
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7485 - loss: 0.5157 - val_accuracy: 0.6861 - val_loss: 0.5412
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7605 - loss: 0.5014 - val_accuracy: 0.7578 - val_loss: 0.5146
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7440 - loss: 0.4924 - val_accuracy: 0.7399 - val_loss: 0.5095
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7754 - loss: 0.4939 - val_accuracy: 0.7354 - val_loss: 0.5281
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7680 - loss: 0.4909 - val_accuracy: 0.7444 - val_loss: 0.5062
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7590 - loss: 0.4804 - val_accuracy: 0.7534 - val_loss: 0.5018
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7620 - loss: 0.4795 - val_accuracy: 0.7489 - val_loss: 0.5032
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7799 - loss: 0.4851 - val_accuracy: 0.7668 - val_loss: 0.4955
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7784 - loss: 0.4743 - val_accuracy: 0.7534 - val_loss: 0.4984
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7814 - loss: 0.4757 - val_accuracy: 0.7848 - val_loss: 0.5011
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7889 - loss: 0.4679 - val_accuracy: 0.7578 - val_loss: 0.4940
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7710 - loss: 0.4708 - val_accuracy: 0.7534 - val_loss: 0.5138
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7814 - loss: 0.4667 - val_accuracy: 0.7623 - val_loss: 0.4919
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7949 - loss: 0.4687 - val_accuracy: 0.7713 - val_loss: 0.4899
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7949 - loss: 0.4630 - val_accuracy: 0.7578 - val_loss: 0.4830
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8009 - loss: 0.4619 - val_accuracy: 0.7444 - val_loss: 0.5092
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7994 - loss: 0.4609 - val_accuracy: 0.7803 - val_loss: 0.4849
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7904 - loss: 0.4563 - val_accuracy: 0.7848 - val_loss: 0.4853
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8069 - loss: 0.4528 - val_accuracy: 0.7803 - val_loss: 0.4788
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7994 - loss: 0.4497 - val_accuracy: 0.7803 - val_loss: 0.4766
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8039 - loss: 0.4574 - val_accuracy: 0.7982 - val_loss: 0.4766
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7874 - loss: 0.4712 - val_accuracy: 0.7399 - val_loss: 0.5239
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7889 - loss: 0.4586 - val_accuracy: 0.7892 - val_loss: 0.4762
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7979 - loss: 0.4507 - val_accuracy: 0.7803 - val_loss: 0.4769
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8099 - loss: 0.4465 - val_accuracy: 0.7892 - val_loss: 0.4797
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8129 - loss: 0.4423 - val_accuracy: 0.7534 - val_loss: 0.5153
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7979 - loss: 0.4506 - val_accuracy: 0.7713 - val_loss: 0.4950
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7964 - loss: 0.4481 - val_accuracy: 0.7892 - val_loss: 0.4749
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8009 - loss: 0.4395 - val_accuracy: 0.7758 - val_loss: 0.4789
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8009 - loss: 0.4541 - val_accuracy: 0.7982 - val_loss: 0.4665
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8069 - loss: 0.4401 - val_accuracy: 0.7937 - val_loss: 0.4750
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8159 - loss: 0.4405 - val_accuracy: 0.7982 - val_loss: 0.4671

# %%
test['Age'].fillna(train['Age'].mean(), inplace=True)
test['Fare'].fillna(train['Fare'].median(), inplace=True)

# %%
Y_pred = model.predict(test)

submission = pd.DataFrame({
    'PassengerId': test_ids,
    'Survived': (Y_pred > 0.5).astype(int).flatten()
})

print(submission)

submission.to_csv('submission.csv', index=False)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
