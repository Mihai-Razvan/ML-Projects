# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('dataset/train.csv')
sub_df = pd.read_csv('dataset/test.csv')

# %%
train_df.head()
# Out:
#    id  age  gender   course  study_hours  class_attendance internet_access  \
# 0   0   21  female     b.sc         7.91              98.8              no
# 1   1   18   other  diploma         4.95              94.8             yes
# 2   2   20  female     b.sc         4.68              92.6             yes
# 3   3   19    male     b.sc         2.00              49.5             yes
# 4   4   23    male      bca         7.65              86.9             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty  \
# 0          4.9       average  online videos             low            easy
# 1          4.7          poor     self-study          medium        moderate
# 2          5.8          poor       coaching            high        moderate
# 3          8.3       average    group study            high        moderate
# 4          9.6          good     self-study            high            easy
#
#    exam_score
# 0        78.3
# 1        46.7
# ...

# %%
train_df = train_df.drop(columns=['id']) # Instead of re-assignment inplace=True could be used

sub_ids = sub_df['id']
sub_df = sub_df.drop(columns=['id'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(train_df.drop(columns='exam_score'), train_df['exam_score'])

# %%
print('===Describe===')
print(X_train['age'].describe())

print('\n===Unique Values===')
print(X_train['age'].value_counts())

print('\n===Null value===')
print(X_train['age'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['age'], bins=len(X_train['age'].unique()), density=True)
plt.show()

for value in X_train['age'].unique():
  filtered = X_train['age'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count    472500.000000
# mean         20.544523
# std           2.260304
# min          17.000000
# 25%          19.000000
# 50%          21.000000
# 75%          23.000000
# max          24.000000
# Name: age, dtype: float64
#
# ===Unique Values===
# age
# 21    64855
# 23    62171
# 20    60526
# 19    59453
# 24    57813
# 18    56686
# 22    56096
# 17    54900
# Name: count, dtype: int64
#
# ===Null value===
# 0
# Average score for '20': 62.53516589564815
# Average score for '17': 62.47781941712205
# Average score for '21': 62.82544210932079
# Average score for '19': 61.737975072746536
# Average score for '24': 62.31786774600869
# Average score for '18': 62.07131427512966
# Average score for '23': 62.89294159656431
# Average score for '22': 63.13105066314888

# %%
print('===Describe===')
print(X_train['gender'].describe())

print('\n===Unique Values===')
print(X_train['gender'].value_counts())

print('\n===Null value===')
print(X_train['gender'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['gender'], bins=len(X_train['gender'].unique()), density=True)
plt.show()

for value in X_train['gender'].unique():
  filtered = X_train['gender'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count     472500
# unique         3
# top        other
# freq      158197
# Name: gender, dtype: object
#
# ===Unique Values===
# gender
# other     158197
# male      158112
# female    156191
# Name: count, dtype: int64
#
# ===Null value===
# 0
# Average score for 'other': 62.796505755482094
# Average score for 'female': 62.57479514184557
# Average score for 'male': 62.140273141823506

# %%
print('===Describe===')
print(X_train['course'].describe())

print('\n===Unique Values===')
print(X_train['course'].value_counts())

print('\n===Null value===')
print(X_train['course'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['course'], bins=len(X_train['course'].unique()), density=True)
plt.show()

for value in X_train['course'].unique():
  filtered = X_train['course'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count     472500
# unique         7
# top       b.tech
# freq       98096
# Name: course, dtype: object
#
# ===Unique Values===
# course
# b.tech     98096
# b.sc       83889
# b.com      83163
# bca        66393
# bba        56834
# ba         46568
# diploma    37557
# Name: count, dtype: int64
#
# ===Null value===
# 0
# Average score for 'b.tech': 62.55325505627141
# Average score for 'ba': 61.872337356124376
# Average score for 'bca': 62.52435660385884
# Average score for 'b.com': 62.47423992640959
# Average score for 'diploma': 62.465110844849164
# Average score for 'b.sc': 62.2999592556831
# Average score for 'bba': 63.28004590561987

# %%
print('===Describe===')
print(X_train['study_hours'].describe())

print('\n===Unique Values Count===')
print(len(X_train['study_hours'].unique()))

print('\n===Null value===')
print(X_train['study_hours'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['study_hours'], bins=250, density=True)
plt.show()
# Out:
# ===Describe===
# count    472500.000000
# mean          4.003075
# std           2.359579
# min           0.080000
# 25%           1.980000
# 50%           4.000000
# 75%           6.050000
# max           7.910000
# Name: study_hours, dtype: float64
#
# ===Unique Values Count===
# 790
#
# ===Null value===
# 0

# %%
print('===Describe===')
print(X_train['class_attendance'].describe())

print('\n===Unique Values Count===')
print(len(X_train['class_attendance'].unique()))

print('\n===Null value===')
print(X_train['class_attendance'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['class_attendance'], bins=25, density=True)
plt.show()
# Out:
# ===Describe===
# count    472500.000000
# mean         71.973087
# std          17.430299
# min          40.600000
# 25%          57.000000
# 50%          72.500000
# 75%          87.200000
# max          99.400000
# Name: class_attendance, dtype: float64
#
# ===Unique Values Count===
# 611
#
# ===Null value===
# 0

# %%
print('===Describe===')
print(X_train['internet_access'].describe())

print('\n===Unique Values===')
print(X_train['internet_access'].value_counts())

print('\n===Null value===')
print(X_train['internet_access'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['internet_access'], bins=len(X_train['internet_access'].unique()), density=True)
plt.show()

for value in X_train['internet_access'].unique():
  filtered = X_train['internet_access'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count     472500
# unique         2
# top          yes
# freq      434681
# Name: internet_access, dtype: object
#
# ===Unique Values===
# internet_access
# yes    434681
# no      37819
# Name: count, dtype: int64
#
# ===Null value===
# 0
# Average score for 'yes': 62.50452669198792
# Average score for 'no': 62.49322692297523

# %%
print('===Describe===')
print(X_train['sleep_hours'].describe())

print('\n===Unique Values===')
print(len(X_train['sleep_hours'].unique()))

print('\n===Null value Count===')
print(X_train['sleep_hours'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['sleep_hours'], bins=9, density=True)
plt.show()
# Out:
# ===Describe===
# count    472500.000000
# mean          7.070731
# std           1.745646
# min           4.100000
# 25%           5.600000
# 50%           7.100000
# 75%           8.600000
# max           9.900000
# Name: sleep_hours, dtype: float64
#
# ===Unique Values===
# 63
#
# ===Null value Count===
# 0

# %%
print('===Describe===')
print(X_train['sleep_quality'].describe())

print('\n===Unique Values Count===')
print(X_train['sleep_quality'].value_counts())

print('\n===Null value Count===')
print(X_train['sleep_quality'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['sleep_quality'], bins=len(X_train['sleep_quality'].unique()), density=True)
plt.show()

for value in X_train['sleep_quality'].unique():
  filtered = X_train['sleep_quality'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count     472500
# unique         3
# top         poor
# freq      160453
# Name: sleep_quality, dtype: object
#
# ===Unique Values Count===
# sleep_quality
# poor       160453
# good       159522
# average    152525
# Name: count, dtype: int64
#
# ===Null value Count===
# 0
# Average score for 'poor': 57.00423489121425
# Average score for 'good': 67.8901256691867
# Average score for 'average': 62.655252502868386

# %%
print('===Describe===')
print(X_train['study_method'].describe())

print('\n===Unique Values Count===')
print(X_train['study_method'].value_counts())

print('\n===Null value Count===')
print(X_train['study_method'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['study_method'], bins=len(X_train['study_method'].unique()), density=True)
plt.show()

for value in X_train['study_method'].unique():
  filtered = X_train['study_method'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count       472500
# unique           5
# top       coaching
# freq         98696
# Name: study_method, dtype: object
#
# ===Unique Values Count===
# study_method
# coaching         98696
# self-study       98318
# group study      92478
# mixed            92319
# online videos    90689
# Name: count, dtype: int64
#
# ===Null value Count===
# 0
# Average score for 'group study': 60.471457027617376
# Average score for 'coaching': 69.28037035948772
# Average score for 'self-study': 57.70711097662686
# Average score for 'online videos': 59.745973469770306
# Average score for 'mixed': 65.11158434341793

# %%
print('===Describe===')
print(X_train['facility_rating'].describe())

print('\n===Unique Values Count===')
print(X_train['facility_rating'].value_counts())

print('\n===Null value Count===')
print(X_train['facility_rating'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['facility_rating'], bins=len(X_train['facility_rating'].unique()), density=True)
plt.show()

for value in X_train['facility_rating'].unique():
  filtered = X_train['facility_rating'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count     472500
# unique         3
# top       medium
# freq      160649
# Name: facility_rating, dtype: object
#
# ===Unique Values Count===
# facility_rating
# medium    160649
# low       159278
# high      152573
# Name: count, dtype: int64
#
# ===Null value Count===
# 0
# Average score for 'high': 66.68344870979793
# Average score for 'medium': 63.02558842569825
# Average score for 'low': 57.973291609638494

# %%
print('===Describe===')
print(X_train['exam_difficulty'].describe())

print('\n===Unique Values Count===')
print(X_train['exam_difficulty'].value_counts())

print('\n===Null value Count===')
print(X_train['exam_difficulty'].isna().sum())

plt.figure(figsize=(10, 8))
plt.hist(X_train['exam_difficulty'], bins=len(X_train['exam_difficulty'].unique()), density=True)
plt.show()

for value in X_train['exam_difficulty'].unique():
  filtered = X_train['exam_difficulty'] == value
  print(f"Average score for '{value}': {Y_train[filtered].mean()}")
# Out:
# ===Describe===
# count       472500
# unique           3
# top       moderate
# freq        265623
# Name: exam_difficulty, dtype: object
#
# ===Unique Values Count===
# exam_difficulty
# moderate    265623
# easy        132525
# hard         74352
# Name: count, dtype: int64
#
# ===Null value Count===
# 0
# Average score for 'hard': 62.627971890466966
# Average score for 'easy': 62.23370124882097
# Average score for 'moderate': 62.60348423141068

# %%
print('===Describe===')
print(Y_train.describe())

print('\n===Unique Values===')
print(len(Y_train.unique()))

print('\n===Null value Count===')
print(Y_train.isna().sum())
# Out:
# ===Describe===
# count    472500.000000
# mean         62.503622
# std          18.923735
# min          19.599000
# 25%          48.800000
# 50%          62.500000
# 75%          76.300000
# max         100.000000
# Name: exam_score, dtype: float64
#
# ===Unique Values===
# 805
#
# ===Null value Count===
# 0

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

columns_to_remove = [
  'gender',
  'course',
  'internet_access',
  'exam_difficulty',
  'age'  #maybe keep
]
X_train = X_train.drop(columns=columns_to_remove)
X_test= X_test.drop(columns=columns_to_remove)

categorical_columns = [
#  'gender',
#  'course',
#  'internet_access',
  'sleep_quality',
  'study_method',
  'facility_rating',
#  'exam_difficulty'
]

label_encoders = {}
for col in categorical_columns:
  label_encoder = LabelEncoder()
  X_train[col] = label_encoder.fit_transform(X_train[col])
  X_test[col] = label_encoder.transform(X_test[col])
  label_encoders[col] = label_encoder

standard_scalers = {}
for col in X_train.columns:
  standard_scaler = StandardScaler()
  X_train[col] = standard_scaler.fit_transform(np.array(X_train[col]).reshape(-1, 1))
  X_test[col] = standard_scaler.transform(np.array(X_test[col]).reshape(-1, 1))
  standard_scalers[col] = standard_scaler

X_train.head()
# Out:
#         study_hours  class_attendance  sleep_hours  sleep_quality  \
# 181194     0.180933         -0.612330    -0.670659       1.208335
# 412713     1.647298          1.252241    -0.957086       1.208335
# 296946    -1.611761         -1.799919     1.620760      -0.020620
# 614660     0.795450          1.148972    -1.415370       1.208335
# 201406    -0.153873          0.167921     0.188623      -1.249576
#
#         study_method  facility_rating
# 181194     -0.693744        -1.249484
# 412713     -1.391244         1.207489
# 296946      1.398758        -1.249484
# 614660      0.701257        -1.249484
# 201406      1.398758         1.207489

# %%
corr = pd.concat([X_train, Y_train], axis=1).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X_train['study_hours'], Y_train, s=1)
plt.xlabel('study_hours')
plt.ylabel('exam_score')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(X_train['class_attendance'], Y_train, s=1)
plt.xlabel('class_attendance')
plt.ylabel('exam_score')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

linear_regression = LinearRegression()
linear_regression.fit(X_train, Y_train)
predictions = linear_regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

print('===MAE===')
print(mean_absolute_error(Y_test, predictions))

print('\n===MSE===')
print(mean_squared_error(Y_test, predictions))

print('\n===RMSE (RMSD)===')
print(root_mean_squared_error(Y_test, predictions))

print('\n===R2===')
print(r2_score(Y_test, predictions))
# Out:
# ===MAE===
# 7.984020239835749
#
# ===MSE===
# 98.92341600967151
#
# ===RMSE (RMSD)===
# 9.946025136187396
#
# ===R2===
# 0.7229584757687979

# %%
sub_df = sub_df.drop(columns=columns_to_remove)

for col in categorical_columns:
  sub_df[col] = label_encoders.get(col).transform(sub_df[col])

for col in sub_df.columns:
  sub_df[col] = standard_scalers.get(col).transform(np.array(sub_df[col]).reshape(-1, 1))

test_predictions = linear_regression.predict(sub_df)

pd.concat([sub_ids, pd.DataFrame(test_predictions)], axis=1).to_csv("predictions.csv", index=False, header=['id', 'exam_score'])
