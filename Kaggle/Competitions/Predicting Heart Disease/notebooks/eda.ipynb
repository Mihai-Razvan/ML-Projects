# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('dataset/train.csv')
train_df.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(train_df.drop(columns=['id', 'Heart Disease']), train_df['Heart Disease'])

# %%
series = X_train['Age']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = []
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages.append(percentage)
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.hist(percentages, bins=5)
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.hist(series, bins=5)
plt.show()

# %%
series = X_train['Sex']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(series.value_counts())

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentages With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.xticks(series.unique())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()

# %%
series = X_train['Chest pain type']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(series.unique())

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentages With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.xticks(series.unique())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()

# %%
series = X_train['BP']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = []
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages.append(percentage)
  # print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.hist(percentages, bins=8)
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.hist(series, bins=8)
plt.show()

# %%
series = X_train['Cholesterol']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = []
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages.append(percentage)
  # print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.hist(percentages, bins=13)
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.hist(series, bins=13)
plt.show()

# %%
series = X_train['FBS over 120']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()
# Out:
# ===Describe===
# count    472500.000000
# mean          0.079831
# std           0.271031
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: FBS over 120, dtype: float64
#
# ===Unique Values===
# 2
#
# ===Percentages With Heart Disease By Value===
# For 0: 44.32%
# For 1: 50.69%

# %%
series = X_train['EKG results']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()
# Out:
# ===Describe===
# count    472500.000000
# mean          0.981128
# std           0.998771
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max           2.000000
# Name: EKG results, dtype: float64
#
# ===Unique Values===
# 3
#
# ===Percentages With Heart Disease By Value===
# For 0: 34.17%
# For 1: 35.65%
# For 2: 55.93%

# %%
series = X_train['Max HR']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = []
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages.append(percentage)
  # print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.hist(percentages, bins=10)
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.hist(series, bins=10)
plt.show()
# Out:
# ===Describe===
# count    472500.000000
# mean        152.835875
# std          19.112425
# min          71.000000
# 25%         142.000000
# 50%         157.000000
# 75%         166.000000
# max         202.000000
# Name: Max HR, dtype: float64
#
# ===Unique Values===
# 93
#
# ===Percentages With Heart Disease By Value===

# %%
series = X_train['Exercise angina']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()

# %%
series = X_train['ST depression']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = []
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages.append(percentage)
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.hist(percentages, bins=8)
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.hist(series, bins=8, density=True)
plt.show()

# %%
series = X_train['Slope of ST']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()

# %%
series = X_train['Number of vessels fluro']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()

# %%
series = X_train['Thallium']

print('===Describe===')
print(series.describe())

print('\n===Unique Values===')
print(len(series.unique()))

print('\n===Percentages With Heart Disease By Value===')
percentages = {}
for value in np.sort(series.unique()):
  mask = (series == value)
  percentage = (Y_train[mask] == 'Presence').sum() / Y_train[mask].count() * 100
  percentages[value] = percentage
  print(f'For {value}: {percentage:.2f}%')

plt.figure(figsize=(8, 8))
plt.title('Percentage With Heart Disease By Value')
plt.bar(percentages.keys(), percentages.values())
plt.show()

plt.figure(figsize=(8, 8))
plt.title('Count Of Total Participants By Values')
plt.bar(series.value_counts().index, series.value_counts().values)
plt.show()

# %%
presence= (Y_train == 'Presence').sum()
absence = (Y_train == 'Absence').sum()
total = presence + absence

print(f'Presence: {(presence / total) * 100:.2f}%\n')
print(f'Absence: {(absence / total) * 100:.2f}%')

plt.figure(figsize=(8, 8))
plt.bar(Y_train.value_counts().index, Y_train.value_counts().values)
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

columns_to_remove = [

]
X_train = X_train.drop(columns=columns_to_remove)
X_test= X_test.drop(columns=columns_to_remove)

categorical_columns = [
]

label_encoders = {}
for col in categorical_columns:
  label_encoder = LabelEncoder()
  X_train[col] = label_encoder.fit_transform(X_train[col])
  X_test[col] = label_encoder.transform(X_test[col])
  label_encoders[col] = label_encoder

test_label_encoder = LabelEncoder()
Y_train = pd.Series(test_label_encoder.fit_transform(Y_train), index=Y_train.index, name='Heart Disease')
Y_test = pd.Series(test_label_encoder.transform(Y_test), index=Y_test.index, name='Heart Disease')

standard_scalers = {}
for col in X_train.columns:
  standard_scaler = StandardScaler()
  X_train[col] = standard_scaler.fit_transform(np.array(X_train[col]).reshape(-1, 1))
  X_test[col] = standard_scaler.transform(np.array(X_test[col]).reshape(-1, 1))
  standard_scalers[col] = standard_scaler

print(X_train.head())
print(Y_train.head())

# %%
age_bins = pd.cut(X_train['Age'], bins=5, labels=False)
print(age_bins)

# %%
from sklearn.feature_selection import mutual_info_classif
import seaborn as sns

mi = mutual_info_classif(X_train, Y_train)
mi_scores = pd.Series(mi, index=X_train.columns).sort_values(ascending=False)
print(mi_scores)

plt.figure(figsize=(10, 6))
sns.barplot(x=mi_scores.values, y=mi_scores.index, palette="viridis")
plt.xlabel('Mutual Information')
plt.ylabel('Feature')
plt.title('Feature Importance by Mutual Information')
plt.tight_layout()
plt.show()

# %%
# No nulls so just ignore imputations

for col in X_train.columns:
  print(X_train[col].isna().sum())
